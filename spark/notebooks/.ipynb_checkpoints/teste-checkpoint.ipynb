# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/30 18:35:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row

df = spark.createDataFrame([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
], schema='a long, b double, c string, d date, e timestamp')
#df
df.printSchema()
# Out:
# root
#  |-- a: long (nullable = true)
#  |-- b: double (nullable = true)
#  |-- c: string (nullable = true)
#  |-- d: date (nullable = true)
#  |-- e: timestamp (nullable = true)

# %%
spark.conf.set('spark.sql.repl.eagerEval.enabled', True)
df
# Out:
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|
# |  2|3.0|string2|2000-02-01|2000-01-02 12:00:00|
# |  3|4.0|string3|2000-03-01|2000-01-03 12:00:00|
# +---+---+-------+----------+-------------------+

# %%
df.show(1, vertical=True)
# Out:
# -RECORD 0------------------
#  a   | 1
#  b   | 2.0
#  c   | string1
#  d   | 2000-01-01
#  e   | 2000-01-01 12:00:00
# only showing top 1 row

# %%
df.select("a", "b", "c").describe().show()
# Out:
# [Stage 9:>                                                          (0 + 8) / 8]
# +-------+---+---+-------+
# |summary|  a|  b|      c|
# +-------+---+---+-------+
# |  count|  3|  3|      3|
# |   mean|2.0|3.0|   NULL|
# | stddev|1.0|1.0|   NULL|
# |    min|  1|2.0|string1|
# |    max|  3|4.0|string3|
# +-------+---+---+-------+

# %%
df.collect()
# Out:
# [Row(a=1, b=2.0, c='string1', d=datetime.date(2000, 1, 1), e=datetime.datetime(2000, 1, 1, 12, 0)),
#  Row(a=2, b=3.0, c='string2', d=datetime.date(2000, 2, 1), e=datetime.datetime(2000, 1, 2, 12, 0)),
#  Row(a=3, b=4.0, c='string3', d=datetime.date(2000, 3, 1), e=datetime.datetime(2000, 1, 3, 12, 0))]

# %%
df.take(2)
# Out:
# [Row(a=1, b=2.0, c='string1', d=datetime.date(2000, 1, 1), e=datetime.datetime(2000, 1, 1, 12, 0)),
#  Row(a=2, b=3.0, c='string2', d=datetime.date(2000, 2, 1), e=datetime.datetime(2000, 1, 2, 12, 0))]

# %%
df.a
# Out:
# Column<'a'>

# %%
df.d
# Out:
# Column<'d'>

# %%
from pyspark.sql import Column
from pyspark.sql.functions import upper

type(df.c) == type(upper(df.c)) == type(df.c.isNull())
# Out:
# True

# %%
df.select(df.c).show()
# Out:
# +-------+
# |      c|
# +-------+
# |string1|
# |string2|
# |string3|
# +-------+

# %%
df.withColumn('upper_c', upper(df.c)).show()
# Out:
# +---+---+-------+----------+-------------------+-------+
# |  a|  b|      c|         d|                  e|upper_c|
# +---+---+-------+----------+-------------------+-------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|STRING1|
# |  2|3.0|string2|2000-02-01|2000-01-02 12:00:00|STRING2|
# |  3|4.0|string3|2000-03-01|2000-01-03 12:00:00|STRING3|
# +---+---+-------+----------+-------------------+-------+

# %%
df_teste = df.filter(df.a == 3)

df_teste.show()
# Out:
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  3|4.0|string3|2000-03-01|2000-01-03 12:00:00|
# +---+---+-------+----------+-------------------+

# %%
df = spark.createDataFrame([
    ['red', 'banana', 1, 10], ['blue', 'banana', 2, 20], ['red', 'carrot', 3, 30],
    ['blue', 'grape', 4, 40], ['red', 'carrot', 5, 50], ['black', 'carrot', 6, 60],
    ['red', 'banana', 7, 70], ['red', 'grape', 8, 80]], schema=['color', 'fruit', 'v1', 'v2'])
df
# Out:
# +-----+------+---+---+
# |color| fruit| v1| v2|
# +-----+------+---+---+
# |  red|banana|  1| 10|
# | blue|banana|  2| 20|
# |  red|carrot|  3| 30|
# | blue| grape|  4| 40|
# |  red|carrot|  5| 50|
# |black|carrot|  6| 60|
# |  red|banana|  7| 70|
# |  red| grape|  8| 80|
# +-----+------+---+---+

# %%
df.groupby('color').avg().show()
# Out:
# +-----+-------+-------+
# |color|avg(v1)|avg(v2)|
# +-----+-------+-------+
# |  red|    4.8|   48.0|
# | blue|    3.0|   30.0|
# |black|    6.0|   60.0|
# +-----+-------+-------+

# %%
df1 = spark.createDataFrame(
    [(20000101, 1, 1.0), (20000101, 2, 2.0), (20000102, 1, 3.0), (20000102, 2, 4.0)],
    ('time', 'id', 'v1'))

df2 = spark.createDataFrame(
    [(20000101, 1, 'x'), (20000101, 2, 'y')],
    ('time', 'id', 'v2'))

def merge_ordered(l, r):
    return pd.merge_ordered(l, r)

df1.groupby('id').cogroup(df2.groupby('id')).applyInPandas(
    merge_ordered, schema='time int, id int, v1 double, v2 string').show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/pyspark/sql/pandas/utils.py:53, in require_minimum_pyarrow_version()
#      52 try:
# ---> 53     import pyarrow
#      55     have_arrow = True
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 12
#       9 def merge_ordered(l, r):
#      10     return pd.merge_ordered(l, r)
# ---> 12 df1.groupby('id').cogroup(df2.groupby('id')).applyInPandas(
#      13     merge_ordered, schema='time int, id int, v1 double, v2 string').show()
#
# File /opt/conda/lib/python3.11/site-packages/pyspark/sql/pandas/group_ops.py:489, in PandasCogroupedOps.applyInPandas(self, func, schema)
#     486 from pyspark.sql.pandas.functions import pandas_udf
#     488 # The usage of the pandas_udf is internal so type checking is disabled.
# --> 489 udf = pandas_udf(
#     490     func, returnType=schema, functionType=PythonEvalType.SQL_COGROUPED_MAP_PANDAS_UDF
#     491 )  # type: ignore[call-overload]
#     493 all_cols = self._extract_cols(self._gd1) + self._extract_cols(self._gd2)
#     494 udf_column = udf(*all_cols)
#
# File /opt/conda/lib/python3.11/site-packages/pyspark/sql/pandas/functions.py:338, in pandas_udf(f, returnType, functionType)
#     306 # The following table shows most of Pandas data and SQL type conversions in Pandas UDFs that
#     307 # are not yet visible to the user. Some of behaviors are buggy and might be changed in the near
#     308 # future. The table might have to be eventually documented externally.
#    (...)
#     335 # Note: Timezone is KST.
#     336 # Note: 'X' means it throws an exception during the conversion.
#     337 require_minimum_pandas_version()
# --> 338 require_minimum_pyarrow_version()
#     340 # decorator @pandas_udf(returnType, functionType)
#     341 is_decorator = f is None or isinstance(f, (str, DataType))
#
# File /opt/conda/lib/python3.11/site-packages/pyspark/sql/pandas/utils.py:60, in require_minimum_pyarrow_version()
#      58     raised_error = error
#      59 if not have_arrow:
# ---> 60     raise ImportError(
#      61         "PyArrow >= %s must be installed; however, "
#      62         "it was not found." % minimum_pyarrow_version
#      63     ) from raised_error
#      64 if LooseVersion(pyarrow.__version__) < LooseVersion(minimum_pyarrow_version):
#      65     raise ImportError(
#      66         "PyArrow >= %s must be installed; however, "
#      67         "your version was %s." % (minimum_pyarrow_version, pyarrow.__version__)
#      68     )
#
# ImportError: PyArrow >= 4.0.0 must be installed; however, it was not found.

# %%
#df.write.orc('zoo.orc')

# %%
#df_teste2 = spark.read.orc('zoo.orc')
#df_teste2.take(2)

# %%
df.createOrReplaceTempView("tableA")
spark.sql("SELECT count(*) from tableA WHERE color = 'red'").show()

# %%
df

# %%
# %%bash
# ls
