# %%
import boto3
from botocore.client import Config

s3 = boto3.client(
    's3',
    endpoint_url='http://minio:9000',
    aws_access_key_id='minioadmin',
    aws_secret_access_key='minioadmin',
    config=Config(signature_version='s3v4'),
    region_name='us-east-1'
)

# %%
# Criando o Bucket

# %%
s3.create_bucket(Bucket='data-lake-bronze')
# Out:
# {'ResponseMetadata': {'RequestId': '18BFC8F8C1089D95',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '0',
#    'location': '/data-lake-bronze',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '18BFC8F8C1089D95',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '626',
#    'x-ratelimit-remaining': '626',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Mon, 06 Jul 2026 19:09:08 GMT'},
#   'RetryAttempts': 0},
#  'Location': '/data-lake-bronze'}

# %%
# adicionando arquivo bruto ao bucket

# %%
s3.upload_file('/home/jovyan/data/workouts.csv', 'data-lake-bronze', 'workouts.csv')
