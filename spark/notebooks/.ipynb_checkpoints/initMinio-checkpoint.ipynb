# %%
import boto3
from botocore.client import Config

s3 = boto3.client(
    's3',
    endpoint_url='http://minio:9000',
    aws_access_key_id='minioadmin',
    aws_secret_access_key='minioadmin',
    config=Config(signature_version='s3v4'),
    region_name='us-east-1'
)

# %%
# Criando o Bucket

# %%
#s3.create_bucket(Bucket='data-lake-bronze')
s3.create_bucket(Bucket='data-lake-silver')
s3.create_bucket(Bucket='data-lake-gold')
# Out:
# {'ResponseMetadata': {'RequestId': '18C0104ACD8BC3A5',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '0',
#    'location': '/data-lake-gold',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '18C0104ACD8BC3A5',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '473',
#    'x-ratelimit-remaining': '473',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Tue, 07 Jul 2026 16:56:05 GMT'},
#   'RetryAttempts': 0},
#  'Location': '/data-lake-gold'}

# %%
# adicionando arquivo bruto ao bucket

# %%
s3.upload_file('/home/jovyan/data/workouts.csv', 'data-lake-bronze', 'workouts.csv')
