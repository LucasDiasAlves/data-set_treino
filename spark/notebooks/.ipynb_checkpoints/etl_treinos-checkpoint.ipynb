# %% [markdown]
# # iniciação do Spark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, desc, to_timestamp, isnull, max, when, lower, regexp_replace

spark = SparkSession.builder \
    .appName("ETL_Treinos_MongoDB") \
    .master("local[*]") \
    .config("spark.executor.memory", "512m") \
    .config("spark.driver.memory", "512m") \
    .config("spark.mongodb.write.connection.uri", "mongodb://root:mongo@mongo_service:27017/treinos_db.historico") \
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000") \
    .config("spark.hadoop.fs.s3a.access.key", "minioadmin") \
    .config("spark.hadoop.fs.s3a.secret.key", "minioadmin") \
    .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
    .config("spark.hadoop.fs.s3a.path.style.access", "true") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
    .getOrCreate()

sc = spark.sparkContext
sc.setLogLevel("ERROR")

spark.conf.set("spark.sql.legacy.timeParserPolicy", "LEGACY")

print("Tudo OK!")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/09 17:12:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Motor do Spark ligado via navegador com sucesso!

# %% [markdown]
# # Tratamento **data-lake-bronze** 🥉
#
# Objetivos:
#
# - Eliminar cargas anotadas erradas;
# - Trocar nome de exercício de "Single Leg Standing Calf Raise (Barbell)" para "Standing Calf Raise (Barbell)";
# - Eliminar marcação de duração de treinos feitas erradas.

# %% [markdown]
# ### Exportando Dado Bruto
#
# a variavel **df_cru** é para receber o arquivo **workouts.csv**, nela pegamos o arquivo diretamente do MinIO, do Bucket **data-lake-bronze**

# %%
df_cru = spark.read.csv("s3a://data-lake-bronze/workouts.csv", header=True, inferSchema=True)

# %% [markdown]
# ## Explorando dados🔍

# %% [markdown]
# ### mostrando tipo de dado

# %%
print("--- Estrutura do Arquivo ---")
df_cru.printSchema()
# Out:
# --- Estrutura do Arquivo ---
# root
#  |-- title: string (nullable = true)
#  |-- start_time: string (nullable = true)
#  |-- end_time: string (nullable = true)
#  |-- description: double (nullable = true)
#  |-- exercise_title: string (nullable = true)
#  |-- superset_id: string (nullable = true)
#  |-- exercise_notes: string (nullable = true)
#  |-- set_index: integer (nullable = true)
#  |-- set_type: string (nullable = true)
#  |-- weight_kg: double (nullable = true)
#  |-- reps: integer (nullable = true)
#  |-- distance_km: double (nullable = true)
#  |-- duration_seconds: integer (nullable = true)
#  |-- rpe: string (nullable = true)

# %% [markdown]
# ### Mostrando as primeiras 5 linhas

# %%
print("\n--- Primeiras 5 linhas ---")
df_cru.show(5)
# Out:
# --- Primeiras 5 linhas ---
# +------------+--------------------+--------------------+-----------+--------------------+-----------+--------------+---------+--------+---------+----+-----------+----------------+----+
# |       title|          start_time|            end_time|description|      exercise_title|superset_id|exercise_notes|set_index|set_type|weight_kg|reps|distance_km|duration_seconds| rpe|
# +------------+--------------------+--------------------+-----------+--------------------+-----------+--------------+---------+--------+---------+----+-----------+----------------+----+
# |Treino 2 e a|13 de jun. de 202...|13 de jun. de 202...|       NULL|            Manguito|       NULL|          NULL|        0|  normal|      2.5|  40|       NULL|            NULL|NULL|
# |Treino 2 e a|13 de jun. de 202...|13 de jun. de 202...|       NULL|            Manguito|       NULL|          NULL|        1|  normal|      2.5|  40|       NULL|            NULL|NULL|
# ...

# %% [markdown]
# ### Ver as 10 primeiras linhas (o 'truncate=False' impede que textos longos fiquem com "...")

# %%
df_cru.show(10, truncate=False)
# Out:
# +------------+-------------------------+-------------------------+-----------+------------------------------+-----------+--------------+---------+--------+---------+----+-----------+----------------+----+
# |title       |start_time               |end_time                 |description|exercise_title                |superset_id|exercise_notes|set_index|set_type|weight_kg|reps|distance_km|duration_seconds|rpe |
# +------------+-------------------------+-------------------------+-----------+------------------------------+-----------+--------------+---------+--------+---------+----+-----------+----------------+----+
# |Treino 2 e a|13 de jun. de 2026, 11:36|13 de jun. de 2026, 12:54|NULL       |Manguito                      |NULL       |NULL          |0        |normal  |2.5      |40  |NULL       |NULL            |NULL|
# ...

# %% [markdown]
# ### Ver estatísticas matemáticas (Média, Mínimo, Máximo) de colunas numéricas

# %%
df_cru.summary().show()
# Out:
# [Stage 6:>                                                          (0 + 1) / 1]
# +-------+--------------------+--------------------+--------------------+-----------------+--------------------+-----------+------------------+------------------+--------+------------------+-----------------+--------------------+-----------------+----+
# |summary|               title|          start_time|            end_time|      description|      exercise_title|superset_id|    exercise_notes|         set_index|set_type|         weight_kg|             reps|         distance_km| duration_seconds| rpe|
# +-------+--------------------+--------------------+--------------------+-----------------+--------------------+-----------+------------------+------------------+--------+------------------+-----------------+--------------------+-----------------+----+
# ...

# %% [markdown]
# ### Encontrar linhas onde uma coluna específica tem um valor problemático

# %%
df_cru.filter(col("weight_kg") > 400).show()
# Out:
# +--------------------+--------------------+--------------------+-----------+--------------------+-----------+--------------+---------+--------+---------+----+-----------+----------------+----+
# |               title|          start_time|            end_time|description|      exercise_title|superset_id|exercise_notes|set_index|set_type|weight_kg|reps|distance_km|duration_seconds| rpe|
# +--------------------+--------------------+--------------------+-----------+--------------------+-----------+--------------+---------+--------+---------+----+-----------+----------------+----+
# |              Quarta|6 de jun. de 2024...|6 de jun. de 2024...|       NULL| Leg Press (Machine)|       NULL|          NULL|        2|  normal|    450.0|   4|       NULL|            NULL|NULL|
# |              Quarta|6 de jun. de 2024...|6 de jun. de 2024...|       NULL| Leg Press (Machine)|       NULL|          NULL|        3|  normal|    470.0|   6|       NULL|            NULL|NULL|
# ...

# %% [markdown]
# ### Filtrar usando múltiplas condições (Use & para E, | para OU)

# %%
#df_cru.filter(
    #(col("idade") > 100) | (col("data_registro").isNull())
#).show()

# %% [markdown]
# ## Tratando a coluna de Data

# %% [markdown]
# ### Antes:

# %%
df_tratado = df_cru
df_tratado.select("start_time","end_time").show()
# Out:
# +--------------------+--------------------+
# |          start_time|            end_time|
# +--------------------+--------------------+
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# |13 de jun. de 202...|13 de jun. de 202...|
# ...

# %% [markdown]
# ### Tratamento:

# %%
df_tratado = df_cru

dicionario = {'jan':'01' , 'fev':'02' , 'mar':'03' , 'abr':'04' , 'mai':'05' ,'jun':'06' ,
              'jul':'07' , 'ago':'08' , 'set':'09' , 'out':'10', 'nov':'11', 'dez':'12',}

# deixando em minusculo os textos
df_tratado = df_tratado.withColumn('start_time', lower(col('start_time')))
df_tratado = df_tratado.withColumn('end_time', lower(col('end_time')))

for mes_texto, mes_numero in dicionario.items():
    df_tratado = df_tratado.withColumn("start_time", regexp_replace(col("start_time"), mes_texto, mes_numero))
    df_tratado = df_tratado.withColumn("end_time", regexp_replace(col("end_time"), mes_texto, mes_numero))

for coluna in ["start_time", "end_time"]:
    
    df_tratado = df_tratado.withColumn(coluna, regexp_replace(col(coluna), " de ", " "))
    
    df_tratado = df_tratado.withColumn(coluna, regexp_replace(col(coluna), ",", ""))
    df_tratado = df_tratado.withColumn(coluna, regexp_replace(col(coluna), "\\.", ""))
        
    df_tratado = df_tratado.withColumn(coluna, to_timestamp(col(coluna), "dd MM yyyy HH:mm"))

# %% [markdown]
# ### Depois:

# %%
df_tratado.select("start_time","end_time").show()
# Out:
# +-------------------+-------------------+
# |         start_time|           end_time|
# +-------------------+-------------------+
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# |2026-06-13 11:36:00|2026-06-13 12:54:00|
# ...

# %% [markdown]
# ## Investigando dados com gráficos

# %%
import matplotlib.pyplot as plt
from pyspark.sql.functions import desc, sum, max

df_resumo_spark = df_tratado.groupBy("exercise_title") \
    .agg(max("weight_kg").alias("carga_total")) \
    .orderBy(desc("carga_total")) \
    .limit(10)

df_pandas = df_resumo_spark.toPandas()

plt.figure(figsize=(10, 5))
plt.bar(df_pandas["exercise_title"], df_pandas["carga_total"], color='royalblue')

plt.title("Top 5 Exercícios com Maior Carga Total", fontsize=14)
plt.xlabel("Exercício", fontsize=12)
plt.ylabel("Carga Total (kg)", fontsize=12)
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# Notamos no gráfico que consta um valor errado no exercício "Rear Delt Reverse Fly (Machine)", com um valor de 509kg, a media de carga destes exercícios é variando de até 109kg.

# %% [markdown]
# ## comparando valores máximos
#
# lista para comparar o valor máximo de cada exercício

# %%
df_analise_cargas = df_cru.groupBy("exercise_title") \
    .agg(
        max("weight_kg").alias("carga_maxima_registrada"),
        count("*").alias("quantidade_de_series")
    ) \
    .orderBy(desc("carga_maxima_registrada"))

df_analise_cargas.show(100, truncate=False)
# Out:
# +------------------------------------------+-----------------------+--------------------+
# |exercise_title                            |carga_maxima_registrada|quantidade_de_series|
# +------------------------------------------+-----------------------+--------------------+
# |Rear Delt Reverse Fly (Machine)           |509.0                  |48                  |
# |Leg Press (Machine)                       |470.0                  |327                 |
# |Calf Press (Machine)                      |300.0                  |3                   |
# |Triceps Rope Pushdown                     |283.0                  |510                 |
# |Deadlift (Barbell)                        |275.0                  |1462                |
# |Squat (Barbell)                           |245.0                  |1589                |
# |Sumo Deadlift                             |245.0                  |260                 |
# ...

# %% [markdown]
# ## verificando cargas
#
# Verificando cargas de exercícios que apresentam erro.<br>
# Exercícios:
#
# - |Rear Delt Reverse Fly (Machine)           |509.0
# - |Triceps Rope Pushdown                     |283.0
#
# -

# %% [markdown]
# ### Crucifixo inverso | Rear Delt Reverse Fly (Machine)

# %%
df_crucifixo_inverso = df_cru.filter(col("exercise_title") == "Rear Delt Reverse Fly (Machine)")

df_analise_crucifixo = df_crucifixo_inverso.groupBy("weight_kg") \
    .agg(count("*").alias("quantidade_de_vezes")) \
    .orderBy(desc("weight_kg"))

df_analise_crucifixo.show(10, truncate=False)
# Out:
# +---------+-------------------+
# |weight_kg|quantidade_de_vezes|
# +---------+-------------------+
# |509.0    |1                  |
# |105.0    |1                  |
# |102.5    |1                  |
# |95.0     |4                  |
# |90.0     |6                  |
# |87.0     |1                  |
# |80.0     |1                  |
# |77.0     |4                  |
# |75.0     |6                  |
# |72.0     |9                  |
# +---------+-------------------+
# only showing top 10 rows

# %% [markdown]
# ### Triceps na Polia | Triceps Rope Pushdown

# %%
df_crucifixo_inverso = df_cru.filter(col("exercise_title") == "Triceps Rope Pushdown")

df_analise_crucifixo = df_crucifixo_inverso.groupBy("weight_kg") \
    .agg(count("*").alias("quantidade_de_vezes")) \
    .orderBy(desc("weight_kg"))

df_analise_crucifixo.show(10, truncate=False)
# Out:
# +---------+-------------------+
# |weight_kg|quantidade_de_vezes|
# +---------+-------------------+
# |283.0    |1                  |
# |42.0     |1                  |
# |40.0     |4                  |
# |38.0     |13                 |
# |36.0     |56                 |
# |34.0     |23                 |
# |33.0     |16                 |
# |32.0     |20                 |
# |31.0     |64                 |
# |29.0     |24                 |
# +---------+-------------------+
# only showing top 10 rows

# %% [markdown]
# ## Subistituindo nomes
#
# Trocar o nome de "Single Leg Standing Calf Raise (Barbell)" para panturrilha Bilateral, pois é uma anotação errada que eu faço.

# %%
df_tratado = df_tratado.withColumn(
    "exercise_title",
    when(col("exercise_title") == "Single Leg Standing Calf Raise (Barbell)", "Standing Calf Raise (Barbell)")
    .otherwise(col("exercise_title"))
)

df_tratado.filter(col("exercise_title") == "Standing Calf Raise (Barbell)").show(5)
# Out:
# +--------------------+-------------------+-------------------+-----------+--------------------+-----------+--------------+---------+--------+---------+----+-----------+----------------+----+
# |               title|         start_time|           end_time|description|      exercise_title|superset_id|exercise_notes|set_index|set_type|weight_kg|reps|distance_km|duration_seconds| rpe|
# +--------------------+-------------------+-------------------+-----------+--------------------+-----------+--------------+---------+--------+---------+----+-----------+----------------+----+
# |Treino b, full le...|2026-06-11 18:55:00|2026-06-11 20:26:00|       NULL|Standing Calf Rai...|       NULL|          NULL|        0|  normal|     90.0|   8|       NULL|            NULL|NULL|
# |Treino b, full le...|2026-06-11 18:55:00|2026-06-11 20:26:00|       NULL|Standing Calf Rai...|       NULL|          NULL|        1|  normal|     90.0|   8|       NULL|            NULL|NULL|
# ...

# %% [markdown]
# ## Teto máximo
# Para corrigir os exercícios anotados com cargas erradas, definindo um limite aceitavel

# %%
df_tratado = df_cru.withColumn(
    "weight_kg",
    when((col("exercise_title").ilike("%Rear Delt Reverse Fly (Machine)%")) & (col("weight_kg") > 105), 105)
    .when((col("exercise_title").ilike("%Triceps Rope Pushdown%")) & (col("weight_kg") > 50), 42)
    .otherwise(col("weight_kg"))
)

# %% [markdown]
# ## Encontrando horas marcadas erradas

# %% [markdown]
# # Linha de código para salvar o csv no data lake silver

# %%
#df_tratado.write \
#    .mode("append") \
#    .format("orc") \
#    .save("s3a://data-lake-silver/workouts_limpos")
